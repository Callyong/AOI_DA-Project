# %%
import pymssql
import pandas as pd
import numpy as np
import re
import datetime

# %%
df = pd.read_csv ('Pass Result.txt', delimiter = ';', header = [0,1])
df.columns = df.columns.map('_'.join)

df
# Out:
#      Unnamed: 0_level_0_Unit  PCB_1. Defect  PCB_2. *N_Defect  \
# 0                   HE_1_2_L              1                 1
# 1                   HE_2_1_L              1                 1
# 2                   HE_1_1_L              1                 1
# 3                   HE_2_2_L              1                 1
# 4                   HE_4_2_L              1                 1
# ...                      ...            ...               ...
# 1254              HE_12_10_L              1                 1
# 1255              HE_14_10_L              1                 1
# 1256               HE_13_9_L              1                 1
# 1257              HE_13_10_L              1                 1
# 1258               HE_14_9_L              1                 1
#
#       PCB_3. Total Area  PCB_4. Areas  PCB_5. Total Area (um)  \
# 0               2989792       2989792              7653867.52
# 1               2990675       2990675              7656128.00
# ...

# %% [markdown]
# ## HRH14111461

# %%
import pymssql
import pandas as pd
import numpy as np
import re
import datetime
import os

# %%
A = 'C:\\Users\\QiauHui_Wong\\QIAO HUI\\MMS#2 Result\\HRH14111461_20211005170600\\Fail\\'

df = pd.read_csv (A + 'Die level_Grab 1 (Fail).txt', delimiter = ';')

# %%
df
# Out:
#        Unnamed: 0        PCB         PCB.1          PCB.2     PCB.3  \
# 0            Unit  1. Defect  2. *N_Defect  3. Total Area  4. Areas
# 1        HE_4_2_L          1             1        2989617   2989617
# 2     HE_9_1_L_74          1             0              0         0
# 3    HE_17_4_L_77          1             1        2988561   2988561
# 4    HE_16_4_L_94          1             1        2992215   2992215
# 5       HE_14_3_L          1             1        2995103   2995103
# 6    HE_13_3_L_77          1             1        2993175   2993175
# 7     HE_8_4_L_77          1             1        2991342   2991342
# 8     HE_4_4_L_77          1             1        2991954   2991954
# 9     HE_1_9_L_74          1             0              0         0
# 10   HE_4_10_L_74          1             1        2991799   2991799
# 11   HE_18_9_L_74          1             0              0         0
# 12  HE_17_12_L_74          1             1        2977794   2977794
#
# ...

# %%
Files = [file for file in os.listdir ('C:\\Users\\QiauHui_Wong\\QIAO HUI\\MMS#2 Result')]

Fail_Unit = pd.DataFrame()

path_fail_list = []

for file in Files:
    #print(file)
    #print('C:\\Users\\QiauHui_Wong\\QIAO HUI\\MMS#2 Result\\' + file)
    path_fail = 'C:\\Users\\QiauHui_Wong\\QIAO HUI\\MMS#2 Result\\' + file
    #print (path_fail + '\\Fail')
    
    
    
    path_fail_list.append( path_fail + '\\Fail')
#print (path_fail_list)
    
for data in path_fail_list:
    
        
    #df = pd.read_csv ('C:\\Users\\QiauHui_Wong\\QIAO HUI\\MMS#2 Result' + Files)
# Out:
# C:\Users\QiauHui_Wong\QIAO HUI\MMS#2 Result\HRH14111461_20211005170600\Fail
# C:\Users\QiauHui_Wong\QIAO HUI\MMS#2 Result\HRH14171115_20211005170432\Fail
# C:\Users\QiauHui_Wong\QIAO HUI\MMS#2 Result\HRH14171167_20211005170318\Fail

# %%
path_fail_list
# Out:
# ['C:\\Users\\QiauHui_Wong\\QIAO HUI\\MMS#2 Result\\HRH14111461_20211005170600\\Fail',
#  'C:\\Users\\QiauHui_Wong\\QIAO HUI\\MMS#2 Result\\HRH14171115_20211005170432\\Fail',
#  'C:\\Users\\QiauHui_Wong\\QIAO HUI\\MMS#2 Result\\HRH14171167_20211005170318\\Fail']

# %%
os.listdir ('C:\\Users\\QiauHui_Wong\\QIAO HUI\\MMS#2 Result')
# Out:
# ['HRH14111461_20211005170600',
#  'HRH14171115_20211005170432',
#  'HRH14171167_20211005170318']

# %%
Files
# Out:
# ['HRH14111461_20211005170600',
#  'HRH14171115_20211005170432',
#  'HRH14171167_20211005170318']

# %%
# C:\Users\QiauHui_Wong\QIAO HUI\MMS#2 Result\HRH14111461_20211005170600\Fail

# %%
list1 = []

for a in range(5):
    print(a)
    list1.append(a)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
list1
# Out:
# [0, 1, 2, 3, 4]

# %%
data
# Out:
# 'C:\\Users\\QiauHui_Wong\\QIAO HUI\\MMS#2 Result\\HRH14171167_20211005170318\\Fail'

# %%
path = ('C:\\Users\\QiauHui_Wong\\QIAO HUI\\MMS#2 Result')
path
# Out:
# 'C:\\Users\\QiauHui_Wong\\QIAO HUI\\MMS#2 Result'

# %%
os.listdir (path)
# Out:
# ['HRH14111461_20211005170600',
#  'HRH14171115_20211005170432',
#  'HRH14171167_20211005170318']

# %%
for f in path:
    fail_path = path + '\\Fail'
fail_path
# Out:
# 'C:\\Users\\QiauHui_Wong\\QIAO HUI\\MMS#2 Result\\Fail'
