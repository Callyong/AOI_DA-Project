# %% [markdown]
# # Qiao Hui's Notebook
# ## Class 1
# - 91

# %%
import pandas as pd

# %%
df = pd.read_csv('Pass Result.txt', delimiter = ';')

# %%
A='C:\\Users\\QiauHui_Wong\\Exercises\\'
df = pd.read_csv(A+'Pass Result.txt', delimiter = ';')

# %%
df.head(5)
# Out:
#   Unnamed: 0        PCB         PCB.1          PCB.2     PCB.3  \
# 0       Unit  1. Defect  2. *N_Defect  3. Total Area  4. Areas
# 1   HE_1_2_L          1             1        2989792   2989792
# 2   HE_2_1_L          1             1        2990675   2990675
# 3   HE_1_1_L          1             1        2991082   2991082
# 4   HE_2_2_L          1             1        2987907   2987907
#
#                 PCB.4          PCB.5              PCB.6        2DM  \
# 0  5. Total Area (um)  6. Areas (um)     7. Angle (deg)  1. Defect
# 1          7653867.52     7653867.52  -1.40505103548571          1
# 2             7656128        7656128   -1.0083907241068          1
# 3          7657169.92     7657169.92  -1.04588453158788          1
# 4          7649041.92     7649041.92  -1.43034552782196          1
#
#          2DM.1  ... BrightField PD (FM).7 BrightField All (FM)  \
# 0  2. N_Defect  ...    8. Inspection Time       1. Defect_Name
# ...
